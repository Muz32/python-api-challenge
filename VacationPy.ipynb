# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
from pathlib import Path

# Import API key
from api_keys import geoapify_key
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
csv_file = Path("output_data/cities.csv")
city_data_df = pd.read_csv(csv_file)

# Display sample data
city_data_df.head()
# Out:
#    City_ID                         City      Lat       Lng  Max Temp  \
# 0        0  edinburgh of the seven seas -37.0676  -12.3116     15.76
# 1        1            port-aux-francais -49.3500   70.2167      3.45
# 2        2                     karratha -20.7377  116.8463     33.78
# 3        3                   bredasdorp -34.5322   20.0403     18.54
# 4        4                      northam  51.0333   -4.2167      7.56
#
#    Humidity  Cloudiness  Wind Speed Country        Date
# 0        77          69       10.68      SH  1713334065
# 1        69          97       12.36      TF  1713334066
# 2        24          82        6.88      AU  1713334066
# 3        72           0        2.33      ZA  1713334067
# 4        79          49        8.14      GB  1713334068

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE
cities_map_plot = city_data_df.hvplot.points(
    'Lng',
    'Lat',
    geo=True,
    tiles='OSM',
    size='Humidity',
    frame_width=800,
    frame_height=600,
    color='City'
)
#Note to self:  It's important to put the 'Lng' (longitude) argument first and the 'Lat' (latitude) argument second when plotting the map to prevent errors from occuring. 
# Display the map
# YOUR CODE HERE
cities_map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# YOUR CODE HERE

ideal_weather_df = city_data_df[
    (city_data_df['Max Temp'] >= 21) & 
    (city_data_df['Max Temp'] <= 27) & 
    (city_data_df['Wind Speed'] <= 7.5) & 
    (city_data_df['Cloudiness'] <= 5)
]

# Drop any rows with null values
# YOUR CODE HERE
ideal_weather_df = ideal_weather_df.dropna()

# Display sample data
# YOUR CODE HERE
ideal_weather_df
# Out:
#      City_ID                   City      Lat       Lng  Max Temp  Humidity  \
# 17        17         margaret river -33.9500  115.0667     25.76        46
# 35        35          alice springs -23.7000  133.8833     26.75        22
# 40        40                 akdepe  42.0551   59.3788     24.98        19
# 54        54               timbuktu  16.7735   -3.0074     22.16        20
# 88        88                  kidal  18.4411    1.4078     21.68        19
# 144      144                 hirara  24.8000  125.2833     25.99        88
# 168      168        plettenberg bay -34.0527   23.3716     22.83        54
# 208      208            ad dilinjat  30.8279   30.5363     25.52        35
# 242      242                  eilat  29.5581   34.9482     25.91        36
# 249      249            broken hill -31.9500  141.4333     22.22        35
# 275      275            kailua-kona  19.6406 -155.9956     25.33        80
# 331      331           south venice  27.0531  -82.4243     21.66        88
# 335      335                  baiti  13.7450  -14.7482     26.39        17
# 371      371               ismailia  30.6043   32.2723     26.24        32
# 385      385               pimentel  -6.8367  -79.9342     21.16        78
# 394      394  san luis rio colorado  32.4631 -114.7767     22.17        15
# 432      432               holualoa  19.6228 -155.9522     23.26        69
# 441      441                  najaf  31.9985   44.3398     26.88        32
# 451      451                 callao -12.0667  -77.1500     21.51        88
# 466      466                beipiao  41.7919  120.7792     26.60        11
# 476      476             oudtshoorn -33.5907   22.2014     25.20        52
# 483      483          cockburn town  21.4612  -71.1419     24.81        81
# 517      517                 forbes -33.3833  148.0167     24.95        30
# 535      535             alexandria  31.2156   29.9553     21.87        58
# 573      573                 gaoual  11.7500  -13.2000     25.04        55
# 594      594              canchungo  12.0672  -16.0333     25.07        80
#
#      Cloudiness  Wind Speed Country        Date
# 17            0        4.58      AU  1713334074
# 35            2        5.14      AU  1713334083
# 40            0        3.88      TM  1713334086
# 54            0        5.13      ML  1713334094
# 88            1        5.28      ML  1713334111
# 144           0        5.63      JP  1713334143
# 168           0        2.76      ZA  1713334155
# 208           0        4.16      EG  1713334176
# 242           0        2.06      IL  1713334195
# 249           0        5.42      AU  1713334114
# 275           0        5.14      US  1713334019
# 331           0        2.57      US  1713334241
# 335           0        0.98      SN  1713334244
# 371           0        4.55      EG  1713334265
# 385           0        6.69      PE  1713334272
# 394           0        3.18      MX  1713334064
# 432           0        5.14      US  1713334297
# 441           0        3.09      IQ  1713334303
# 451           0        1.54      PE  1713334308
# 466           2        4.71      CN  1713334316
# 476           0        2.57      ZA  1713334322
# 483           4        6.18      TC  1713334326
# 517           0        2.69      AU  1713334343
# 535           0        5.32      EG  1713334353
# 573           4        0.50      GN  1713334374
# 594           0        1.56      GW  1713334385

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
# YOUR CODE HERE

hotel_df = ideal_weather_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
# YOUR CODE HERE
hotel_df['Hotel Name'] = ''

# Display sample data
# YOUR CODE HERE
hotel_df
# Out:
#                       City Country      Lat       Lng  Humidity Hotel Name
# 17          margaret river      AU -33.9500  115.0667        46
# 35           alice springs      AU -23.7000  133.8833        22
# 40                  akdepe      TM  42.0551   59.3788        19
# 54                timbuktu      ML  16.7735   -3.0074        20
# 88                   kidal      ML  18.4411    1.4078        19
# 144                 hirara      JP  24.8000  125.2833        88
# 168        plettenberg bay      ZA -34.0527   23.3716        54
# 208            ad dilinjat      EG  30.8279   30.5363        35
# 242                  eilat      IL  29.5581   34.9482        36
# 249            broken hill      AU -31.9500  141.4333        35
# 275            kailua-kona      US  19.6406 -155.9956        80
# 331           south venice      US  27.0531  -82.4243        88
# 335                  baiti      SN  13.7450  -14.7482        17
# 371               ismailia      EG  30.6043   32.2723        32
# 385               pimentel      PE  -6.8367  -79.9342        78
# 394  san luis rio colorado      MX  32.4631 -114.7767        15
# 432               holualoa      US  19.6228 -155.9522        69
# 441                  najaf      IQ  31.9985   44.3398        32
# 451                 callao      PE -12.0667  -77.1500        88
# 466                beipiao      CN  41.7919  120.7792        11
# 476             oudtshoorn      ZA -33.5907   22.2014        52
# 483          cockburn town      TC  21.4612  -71.1419        81
# 517                 forbes      AU -33.3833  148.0167        30
# 535             alexandria      EG  31.2156   29.9553        58
# 573                 gaoual      GN  11.7500  -13.2000        55
# 594              canchungo      GW  12.0672  -16.0333        80

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000 # YOUR CODE HERE
categories = "accommodation.hotel"
params = {"categories": categories, # YOUR CODE HERE
    "apiKey":geoapify_key 
   
}  

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    # YOUR CODE HERE
    
    longitude = row["Lng"]
    latitude = row["Lat"]

    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{ latitude},{radius}"# YOUR CODE HERE
    params["bias"] = f"proximity:{longitude},{ latitude}" # YOUR CODE HERE
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params) # YOUR CODE HERE
    
    # Convert the API response to JSON format
    name_address = name_address.json() # YOUR CODE HERE
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# margaret river - nearest hotel: Margaret River Hotel
# alice springs - nearest hotel: Aurora Alice Springs
# akdepe - nearest hotel: No hotel found
# timbuktu - nearest hotel: Hotel La Maison
# kidal - nearest hotel: No hotel found
# hirara - nearest hotel: 古謝そば屋
# plettenberg bay - nearest hotel: Milkwood Manor
# ad dilinjat - nearest hotel: No hotel found
# eilat - nearest hotel: Melony Club
# broken hill - nearest hotel: Ibis Styles
# kailua-kona - nearest hotel: Kona Seaside Hotel
# south venice - nearest hotel: Kon-Tiki Motel
# baiti - nearest hotel: No hotel found
# ismailia - nearest hotel: Mercure
# pimentel - nearest hotel: Hospedaje Calle del Sol
# san luis rio colorado - nearest hotel: HOTEL SAN ANGEL
# holualoa - nearest hotel: Kona Hotel
# najaf - nearest hotel: مديرية مجاري النجف
# callao - nearest hotel: Casa Ronald
# beipiao - nearest hotel: No hotel found
# oudtshoorn - nearest hotel: The Pearl
# cockburn town - nearest hotel: The Salt Raker Inn
# forbes - nearest hotel: No hotel found
# alexandria - nearest hotel: Smoha Zahran Haus (7th floor)
# gaoual - nearest hotel: Hotel
# canchungo - nearest hotel: Hotel Pereira
#                       City Country      Lat       Lng  Humidity  \
# 17          margaret river      AU -33.9500  115.0667        46
# 35           alice springs      AU -23.7000  133.8833        22
# 40                  akdepe      TM  42.0551   59.3788        19
# 54                timbuktu      ML  16.7735   -3.0074        20
# 88                   kidal      ML  18.4411    1.4078        19
# 144                 hirara      JP  24.8000  125.2833        88
# 168        plettenberg bay      ZA -34.0527   23.3716        54
# 208            ad dilinjat      EG  30.8279   30.5363        35
# 242                  eilat      IL  29.5581   34.9482        36
# 249            broken hill      AU -31.9500  141.4333        35
# 275            kailua-kona      US  19.6406 -155.9956        80
# 331           south venice      US  27.0531  -82.4243        88
# 335                  baiti      SN  13.7450  -14.7482        17
# 371               ismailia      EG  30.6043   32.2723        32
# 385               pimentel      PE  -6.8367  -79.9342        78
# 394  san luis rio colorado      MX  32.4631 -114.7767        15
# 432               holualoa      US  19.6228 -155.9522        69
# 441                  najaf      IQ  31.9985   44.3398        32
# 451                 callao      PE -12.0667  -77.1500        88
# 466                beipiao      CN  41.7919  120.7792        11
# 476             oudtshoorn      ZA -33.5907   22.2014        52
# 483          cockburn town      TC  21.4612  -71.1419        81
# 517                 forbes      AU -33.3833  148.0167        30
# 535             alexandria      EG  31.2156   29.9553        58
# 573                 gaoual      GN  11.7500  -13.2000        55
# 594              canchungo      GW  12.0672  -16.0333        80
#
#                         Hotel Name
# 17            Margaret River Hotel
# 35            Aurora Alice Springs
# 40                  No hotel found
# 54                 Hotel La Maison
# 88                  No hotel found
# 144                          古謝そば屋
# 168                 Milkwood Manor
# 208                 No hotel found
# 242                    Melony Club
# 249                    Ibis Styles
# 275             Kona Seaside Hotel
# 331                 Kon-Tiki Motel
# 335                 No hotel found
# 371                        Mercure
# 385        Hospedaje Calle del Sol
# 394                HOTEL SAN ANGEL
# 432                     Kona Hotel
# 441             مديرية مجاري النجف
# 451                    Casa Ronald
# 466                 No hotel found
# 476                      The Pearl
# 483             The Salt Raker Inn
# 517                 No hotel found
# 535  Smoha Zahran Haus (7th floor)
# 573                          Hotel
# 594                  Hotel Pereira

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE

hotels_map_plot = hotel_df.hvplot.points(
    'Lng',
    'Lat',
    geo=True,
    tiles='OSM',
    size='Humidity',
    frame_width=800,
    frame_height=600,
    color='City',
    hover_cols= ["Hotel Name", "Country"]
)
# Display the map
# YOUR CODE HERE
hotels_map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
